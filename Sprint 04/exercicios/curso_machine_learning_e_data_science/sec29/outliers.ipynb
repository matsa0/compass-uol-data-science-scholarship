# %%
import pandas as pd
import plotly.express as px

# %%
df_credit = pd.read_csv('../data/credit_data.csv')

# %%
df_credit
# Out:
#       clientid        income        age         loan  default
# 0            1  66155.925095  59.017015  8106.532131        0
# 1            2  34415.153966  48.117153  6564.745018        0
# 2            3  57317.170063  63.108049  8020.953296        0
# 3            4  42709.534201  45.751972  6103.642260        0
# 4            5  66952.688845  18.584336  8770.099235        1
# ...        ...           ...        ...          ...      ...
# 1995      1996  59221.044874  48.518179  1926.729397        0
# 1996      1997  69516.127573  23.162104  3503.176156        0
# 1997      1998  44311.449262  28.017167  5522.786693        1
# 1998      1999  43756.056605  63.971796  1622.722598        0
# 1999      2000  69436.579552  56.152617  7378.833599        0
#
# [2000 rows x 5 columns]

# %%
df_credit.isnull().sum()
# Out:
# clientid    0
# income      0
# age         3
# loan        0
# default     0
# dtype: int64

# %%
df_credit.dropna(inplace=True)

# %% [markdown]
# # Boxplot

# %%
# Outliers idade
g = px.box(df_credit, y='age', height=600, width=600)
g.show()
#outliers - idades negativas?

# %%
outliers_age = df_credit[df_credit['age'] < 0]
outliers_age
# Out:
#     clientid        income        age         loan  default
# 15        16  50501.726689 -28.218361  3977.287432        0
# 21        22  32197.620701 -52.423280  4244.057136        0
# 26        27  63287.038908 -36.496976  9595.286289        0

# %%
# Outliers loan
g = px.box(df_credit, y='loan', height=700, width=600)
g.show()
#clientes com dívida muito alta

# %%
outliers_loan = df_credit[df_credit['loan'] > 13300]
outliers_loan
# Out:
#       clientid        income        age          loan  default
# 1378      1379  69755.320163  44.543682  13766.051239        0
# 1584      1585  67289.585683  26.727400  13376.797706        1
# 1801      1802  67802.694456  49.037987  13443.473176        0

# %% [markdown]
# # Scatter

# %%
# Income x age
g = px.scatter(x = df_credit['income'], y = df_credit['age'])
g.show()

# %%
# Income x loan
g = px.scatter(x = df_credit['income'], y = df_credit['loan'])
g.show()

# %%
df_census = pd.read_csv('../data/census.csv')
df_census
# Out:
#        age          workclass  final-weight    education  education-num  \
# 0       39          State-gov         77516    Bachelors             13
# 1       50   Self-emp-not-inc         83311    Bachelors             13
# 2       38            Private        215646      HS-grad              9
# 3       53            Private        234721         11th              7
# 4       28            Private        338409    Bachelors             13
# ...    ...                ...           ...          ...            ...
# 32556   27            Private        257302   Assoc-acdm             12
# 32557   40            Private        154374      HS-grad              9
# 32558   58            Private        151910      HS-grad              9
# 32559   22            Private        201490      HS-grad              9
# 32560   52       Self-emp-inc        287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# ...

# %%
# Age x final weight
g = px.scatter(x = df_census['age'], y = df_census['final-weight'])
g.show()
