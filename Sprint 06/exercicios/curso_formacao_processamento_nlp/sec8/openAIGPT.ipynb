# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install openai

# %%
from openai import OpenAI

# %%
client = OpenAI(api_key="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")
model = "gpt-4o-mini"

# %%
response = client.chat.completions.create(
    model = model,
    messages = [
        {
            "role": "user",
            "content": "Tell me a joke"
        }
    ]
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-12-717f17669023> in <cell line: 0>()
# ----> 1 response = client.chat.completions.create(
#       2     model = model,
#       3     messages = [
#       4         {
#       5             "role": "user",
#
# /usr/local/lib/python3.11/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     277                         msg = f"Missing required argument: {quote(missing[0])}"
#     278                 raise TypeError(msg)
# --> 279             return func(*args, **kwargs)
#     280
#     281         return wrapper  # type: ignore
#
# ...
