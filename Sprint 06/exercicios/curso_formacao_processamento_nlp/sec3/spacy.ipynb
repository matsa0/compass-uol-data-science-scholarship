# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import spacy

# %%
print(spacy.__version__)
# Out:
# 3.7.5

# %%
# !python -m spacy download 'pt_core_news_lg'
# Out:
# Collecting pt-core-news-lg==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_lg-3.7.0/pt_core_news_lg-3.7.0-py3-none-any.whl (568.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.2/568.2 MB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from pt-core-news-lg==3.7.0) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2024.12.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.1.2)
# Installing collected packages: pt-core-news-lg
# Successfully installed pt-core-news-lg-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp = spacy.load('pt_core_news_lg')

# %%
print(type(nlp))
# Out:
# <class 'spacy.lang.pt.Portuguese'>

# %%
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'morphologizer', 'parser', 'lemmatizer', 'attribute_ruler', 'ner']

# %%
document = nlp("As ações do Magazine Luiza S.A., Franca, Brasil, acumuluram baixa de 70% ano.")

# %%
len(document.vocab)
# Out:
# 365

# %%
print(type(document))
# Out:
# <class 'spacy.tokens.doc.Doc'>

# %% [markdown]
# # Tokens

# %%
for token in document:
  print(token.text)
# Out:
# As
# ações
# do
# Magazine
# Luiza
# S.A.
# ,
# Franca
# ,
# Brasil
# ,
# acumuluram
# baixa
# de
# 70
# %
# ano
# .

# %%
print(document[3:5])
# Out:
# Magazine Luiza

# %%
print(len(document))
# Out:
# 18

# %%
print("Tokens: ", [token.text for token in document])
print("\n")
print("Stop word: ", [token.is_stop for token in document])
print("Alfanumérico: ", [token.is_alpha for token in document])
print("Maiúsculo: ", [token.is_upper for token in document])
print("Pontuação: ", [token.is_punct for token in document])
print("Número: ", [token.like_num for token in document])
print("Sentença inicial: ", [token.is_sent_start for token in document])
print("Sentença final: ", [token.is_sent_end for token in document])
# Out:
# Tokens:  ['As', 'ações', 'do', 'Magazine', 'Luiza', 'S.A.', ',', 'Franca', ',', 'Brasil', ',', 'acumuluram', 'baixa', 'de', '70', '%', 'ano', '.']
#
#
# Stop word:  [True, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False]
# Alfanumérico:  [True, True, True, True, True, False, False, True, False, True, False, True, True, True, False, False, True, False]
# Maiúsculo:  [False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False]
# Pontuação:  [False, False, False, False, False, False, True, False, True, False, True, False, False, False, False, True, False, True]
# Número:  [False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False]
# Sentença inicial:  [True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]
# Sentença final:  [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True]

# %%
for token in document:
  if token.like_num:
    print(token)
  elif token.is_punct:
    print(token)
# Out:
# ,
# ,
# ,
# 70
# %
# .

# %% [markdown]
# # Pos-Tagging e Dependências

# %%
for token in document:
  print(token.text, ' - ', token.morph)
# Out:
# As  -  Definite=Def|Gender=Fem|Number=Plur|PronType=Art
# ações  -  Gender=Fem|Number=Plur
# do  -  Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# Magazine  -  Gender=Fem|Number=Sing
# Luiza  -  Gender=Fem|Number=Sing
# S.A.  -  Number=Sing
# ,  -
# Franca  -  Gender=Fem|Number=Sing
# ,  -
# Brasil  -  Gender=Masc|Number=Sing
# ,  -
# acumuluram  -  Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin
# baixa  -  Gender=Fem|Number=Sing
# de  -
# 70  -  NumType=Card
# %  -
# ano  -  Gender=Masc|Number=Sing
# .  -

# %%
for token in document:
  print(token.text, ' - ', token.tag_)
# Out:
# As  -  DET
# ações  -  NOUN
# do  -  ADP
# Magazine  -  PROPN
# Luiza  -  PROPN
# S.A.  -  PROPN
# ,  -  PUNCT
# Franca  -  PROPN
# ,  -  PUNCT
# Brasil  -  PROPN
# ,  -  PUNCT
# acumuluram  -  VERB
# baixa  -  NOUN
# de  -  ADP
# 70  -  NUM
# %  -  SYM
# ano  -  NOUN
# .  -  PUNCT

# %% [markdown]
# # Entidades nomeadas

# %%
for ent in document.ents:
  print(ent.text, ' - ', ent.label_)
# Out:
# Magazine Luiza S.A.  -  ORG
# Franca  -  LOC
# Brasil  -  LOC

# %% [markdown]
# # Stop Words

# %%
for token in document:
  if token.is_stop:
    print(token.text)
# Out:
# As
# do
# de

# %%
for words in nlp.Defaults.stop_words:
  print(words)
# Out:
# oitava
# estará
# através
# sim
# favor
# vos
# sexta
# usa
# pelos
# novo
# aos
# tu
# fazem
# seis
# eventual
# esses
# sois
# parece
# des
# quer
# quieto
# disso
# demais
# cada
# mais
# quarta
# mas
# vós
# primeiro
# onze
# umas
# quinze
# aquela
# entre
# vosso
# isto
# cedo
# grandes
# número
# estiveste
# dentro
# fazer
# neste
# os
# era
# teu
# relação
# tive
# me
# sétima
# nos
# foram
# algumas
# cujo
# três
# contudo
# lado
# grande
# tanto
# posição
# ali
# nuns
# foi
# ontem
# porque
# questão
# cinco
# nosso
# máximo
# possivelmente
# tem
# vossos
# este
# maior
# aqueles
# vens
# nenhuma
# pelo
# vão
# essas
# vocês
# acerca
# ambos
# segunda
# eles
# muitos
# vezes
# longe
# desse
# deverá
# fez
# tão
# e
# tivemos
# apontar
# partir
# fazeis
# forma
# toda
# pôde
# são
# faço
# seria
# tiveste
# todo
# meio
# pode
# vai
# estiveram
# pontos
# se
# momento
# assim
# lugar
# põe
# isso
# também
# diz
# coisa
# dezassete
# teve
# for
# foste
# minhas
# ir
# treze
# talvez
# maiorias
# quarto
# ou
# tarde
# fui
# ela
# parte
# pouco
# ser
# da
# suas
# boa
# estás
# outros
# estivemos
# breve
# fomos
# fazia
# somos
# eu
# sua
# menor
# conhecido
# sabe
# a
# inicio
# oito
# atrás
# poderá
# quem
# adeus
# bom
# dezasseis
# esta
# já
# pelas
# sou
# vossas
# ao
# área
# seus
# tentar
# pouca
# numa
# terceira
# daquele
# iniciar
# essa
# mil
# põem
# sem
# quieta
# próxima
# apoio
# têm
# dão
# estão
# tempo
# corrente
# um
# lhe
# estar
# naquele
# sétimo
# tenho
# além
# vais
# tudo
# nesse
# que
# certeza
# sexto
# outra
# estado
# em
# sob
# direita
# terceiro
# todas
# portanto
# na
# qual
# estas
# deve
# ambas
# próprio
# pois
# apenas
# quê
# tivestes
# baixo
# você
# dessa
# és
# minha
# muito
# tentaram
# num
# nove
# não
# vez
# com
# obrigado
# perto
# uns
# menos
# nossos
# dos
# deste
# quanto
# segundo
# comprido
# dezanove
# dizem
# cima
# estivestes
# nível
# podia
# aquele
# por
# nunca
# bastante
# quatro
# nesta
# naquela
# sempre
# quinto
# conhecida
# tendes
# aqui
# então
# querem
# ponto
# grupo
# final
# certamente
# conselho
# tens
# nós
# valor
# é
# podem
# algo
# cento
# aquelas
# quando
# embora
# esse
# tua
# comprida
# enquanto
# duas
# como
# nova
# nossa
# logo
# de
# sistema
# zero
# onde
# porquê
# puderam
# só
# fazemos
# fostes
# nem
# ter
# mês
# quero
# fim
# estive
# desde
# bem
# dizer
# aquilo
# mal
# tentei
# porquanto
# todos
# às
# nossas
# números
# faz
# poder
# está
# irá
# te
# vinda
# ora
# fora
# usar
# ainda
# tente
# teus
# ligado
# dois
# lá
# alguns
# caminho
# exemplo
# sobre
# dar
# tais
# diante
# nada
# sete
# aí
# nessa
# pela
# temos
# vinte
# outras
# dá
# vêm
# oitavo
# ademais
# nas
# obrigada
# elas
# posso
# apoia
# ele
# fará
# agora
# povo
# meu
# depois
# quais
# saber
# maioria
# ver
# doze
# do
# debaixo
# das
# tal
# devem
# dez
# cuja
# tanta
# último
# desta
# geral
# novos
# meses
# qualquer
# tipo
# tuas
# daquela
# cá
# vindo
# o
# somente
# vários
# antes
# primeira
# veja
# dezoito
# tiveram
# mesmo
# após
# as
# custa
# novas
# no
# esteve
# estes
# quinta
# porém
# vossa
# contra
# seu
# próximo
# sei
# estou
# uma
# estava
# à
# meus
# até
# pegar
# para
# possível
# inclusive
# local
# falta
# fazes
# vem
# catorze

# %%
nlp.Defaults.stop_words.add("eita")
nlp.vocab['eita'].is_stop = True

# %% [markdown]
# ## Removendo Stop Words do Corpus

# %%
document_without_stop = []
for token in document:
  if not token.is_stop:
    document_without_stop.append(token)

document_without_stop
# Out:
# [ações,
#  Magazine,
#  Luiza,
#  S.A.,
#  ,,
#  Franca,
#  ,,
#  Brasil,
#  ,,
#  acumuluram,
#  baixa,
#  70,
#  %,
#  ano,
#  .]

# %% [markdown]
# # Vocabulário
#
# cada palavra é representada por um Hash

# %%
print("Hash: ", nlp.vocab.strings["dados"])
print("Hash: ", document.vocab.strings["dados"])
print("String: ", nlp.vocab.strings[6013848609874238634])
# Out:
# Hash:  6013848609874238634
# Hash:  6013848609874238634
# String:  dados

# %%
lex = nlp.vocab["dados"]
print(lex.text, " - ", lex.orth, " - ", lex.is_alpha, " - ", lex.is_lower)
# Out:
# dados  -  6013848609874238634  -  True  -  True

# %%
# formato da palvara
print(nlp("dados").vector.shape)
# Out:
# (300,)

# %%
# relacão da palavra com outras 300
print(nlp("dados").vector)
# Out:
# [-1.8078e+00 -2.8421e+00 -5.5345e-01 -4.0565e+00 -2.3565e+00  4.7295e+00
#  -3.3508e+00 -1.2036e+00 -5.3749e+00 -7.5768e-01 -2.0015e+00  5.3618e+00
#   2.2789e-01  1.2136e+00 -1.4418e+00 -3.0621e+00  2.2060e+00  1.1943e+00
#  -1.8689e+00 -5.9128e+00 -5.1929e-01  2.1897e+00 -2.4651e+00  1.7600e+00
#  -5.6308e+00  1.0053e+00  7.3080e-01  2.0417e-01 -6.0370e+00  1.7474e+00
#   2.0375e+00  2.7541e+00 -1.0423e+00  1.7632e+00 -1.4484e+00 -2.4344e+00
#  -8.6094e-01  1.7867e+00 -4.9920e+00 -3.1162e+00 -5.3973e-01  2.4241e+00
#   4.4410e-01 -4.7503e+00  2.1383e+00  3.8537e-01 -2.2418e+00  5.8104e+00
#  -1.1731e+00  2.4686e-02 -1.8413e+00 -5.9321e+00 -7.0872e-03 -2.3093e+00
#   5.5101e+00 -4.1795e-01  2.9754e+00  3.6709e-01 -8.0867e-01 -1.3751e+00
#   4.8132e+00 -2.2835e+00 -2.0920e-01  1.2578e+00  4.3466e+00  1.3846e+00
#  -1.5847e+00  3.3322e+00 -4.3669e+00  1.8883e+00 -1.2312e+00  3.7902e-01
#   8.6331e-01 -4.0607e+00 -1.3444e+00  4.5210e+00  2.2995e-01 -5.9245e+00
#  -2.0598e-01 -3.1810e+00 -3.8640e+00  7.2114e+00  3.1034e+00 -4.2856e+00
#   5.4147e+00 -7.2224e+00  4.3610e+00 -2.6696e+00  1.9245e+00 -2.6187e+00
#  -5.1742e+00  1.0513e-01  1.9628e+00  1.0356e+00  6.8692e+00 -7.3888e-01
#   3.8783e+00  4.1958e+00 -8.8872e+00 -1.8452e+00  5.2786e+00  4.2920e+00
#  -4.2204e-01  1.0009e+00  4.2165e-01  1.1927e+00 -8.4580e-01 -2.6577e+00
#   1.5024e+00  4.4229e-01 -2.5251e+00 -7.1781e-01  7.0878e-01  1.7207e+00
#   3.8369e+00 -1.5924e+00  2.0870e+00  4.3324e-01 -1.0600e+00  2.7058e+00
#   1.3282e+00 -7.1241e+00 -1.3663e+00 -3.0763e+00  2.7714e+00  1.3094e+00
#   1.6072e+00  3.6821e+00  5.3843e+00 -3.5457e-02 -2.9616e+00  1.5253e+00
#   2.0812e-01  6.0771e-01 -5.5709e-01  7.5687e+00 -9.1431e-01 -3.0477e+00
#   1.2046e+00  5.3871e-01  5.7112e-01  2.2039e+00 -5.1948e-02 -2.6353e+00
#  -2.8517e+00  1.8675e-01  2.1013e+00  7.5272e-01 -8.7856e+00 -1.4493e+00
#  -7.9085e-01 -1.6936e+00  1.4793e-02 -9.9357e+00  3.7818e+00 -1.7839e+00
#   1.5425e+00 -3.0899e-02 -5.1442e+00  4.2366e-01  3.2065e+00  3.9226e+00
#  -1.4392e-02  1.5862e+00  7.0632e+00  7.5689e+00 -3.4420e+00 -6.1376e+00
#   5.0851e-01 -6.3689e-01 -1.8791e-01  1.9850e+00  3.0888e+00 -3.0506e+00
#   1.1851e-01 -1.2290e+00  7.6061e+00  1.8492e-01 -2.7509e+00 -1.3448e+00
#   1.9857e+00 -2.4650e+00 -2.0810e+00  5.6084e+00 -7.3379e-01  1.1205e+00
#   1.3258e-02 -7.0243e-01  1.0118e+00  3.8903e+00 -1.2631e+00 -2.7544e+00
#   9.3134e-01  2.7516e+00 -1.6767e+00  4.5501e+00 -4.9452e-01  1.0644e+00
#  -1.2653e+00  3.9671e-01 -6.4705e+00 -7.7726e-01 -3.9283e+00  7.9536e+00
#   2.0967e+00  1.2104e+00  3.4474e+00 -2.2200e+00 -4.9974e+00  3.1827e-01
#  -1.0450e+00 -2.1353e+00  1.0529e+00 -1.6568e+00 -3.0012e+00  4.2834e+00
#   6.9626e-01  4.5401e+00 -1.7153e-01 -5.9982e-01  3.6147e+00 -3.4545e+00
#   3.6811e-01 -4.1399e+00 -1.8144e+00  2.9088e+00  8.9164e-01 -2.4783e+00
#  -3.6413e+00 -3.4140e-01 -8.0959e-01 -4.7451e+00  4.2487e+00  6.6012e+00
#  -5.1022e+00  1.5260e+00  3.5160e+00 -1.4569e+00  1.4442e+00  6.8183e+00
#  -5.0775e+00  1.0688e+00  4.8081e+00  3.6586e+00 -3.0766e+00 -8.5266e-01
#  -3.3401e+00 -5.2864e+00 -9.1773e-01 -1.8197e+00  2.0192e+00 -6.7857e+00
#  -3.6542e+00 -3.4654e+00  3.3276e+00  9.0340e-02 -3.0743e+00  3.3329e+00
#  -2.6458e+00  2.6557e-02 -4.7538e-01  2.7974e+00  5.3304e+00  2.9937e+00
#   3.8899e+00 -3.3433e+00 -3.4940e+00  2.1821e+00  8.1387e+00  3.5272e-01
#   4.8159e+00 -7.8327e-01 -1.2468e+00  5.9163e+00 -6.0636e-02 -4.3255e-01
#  -1.2690e+00 -3.2938e+00  3.2941e-02 -9.3676e-01 -7.1630e-01  1.4011e+00
#   1.8334e+00 -1.4261e+00 -1.9903e+00 -1.4721e+00  2.1466e+00 -2.0949e+00
#  -7.6855e-01 -2.8615e+00 -2.0466e+00  7.1870e-01 -1.1195e+00 -3.1117e+00
#   1.5789e-01 -4.0320e+00 -9.2665e-01 -6.2468e-01 -2.7397e+00  6.0866e-01]

# %% [markdown]
# # Similaridade
#
# baseada em contexto
#
# retorna um valor(métrica de similaridade)
#
# a métrica é o coseno, valor entre 0 e 1.(quando mais próximo de 1, mais semelhança)
#
# matcher busca um padrão, retorna se encontra

# %%
document = nlp("Ele viaja frequentemente de moto")
document2 = nlp("Ele viaja regularmente de carro")

print(document.similarity(document2))
# Out:
# 0.9502978109419011

# %%
document3 = nlp("Devemos dizer comprimento ou cumprimento?")
tokenA = document3[2]
tokenB = document3[4]

print(f"Similaridade entre {tokenA} e {tokenB}: {(tokenA.similarity(tokenB))}")
# Out:
# Similaridade entre comprimento e cumprimento: 0.5804340243339539

# %% [markdown]
# # Busca de expressões com matching

# %%
from typing import Match
from spacy.matcher import Matcher

# %%
document5 = nlp("Você pode ligar para (51) - 9964656570 ou (11) 12344988")

matcher = Matcher(nlp.vocab)
pattern = [{"ORTH": "("}, {"SHAPE": "dd"}, {"ORTH": ")"}, {"ORTH": "-", "OP": "?"}, {"IS_DIGIT": True}]
matcher.add("Number", [pattern])
matches = matcher(document5)

for id, start, end in matches:
  print(document5[start:end])
# Out:
# (51) - 9964656570
# (11) 12344988

# %% [markdown]
# # Displacy
#
# Módulo do Spacy para visualização

# %%
from spacy import displacy

document = nlp("As ações do Magazine Luiza S.A., Franca, Brasil, acumuluram baixa de 70% ano.")
displacy.render(document, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">As ações do
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Magazine Luiza S.A.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Franca
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brasil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , acumuluram baixa de 70% ano.</div></span>

# %%
displacy.render(document, style="dep", jupyter=True,
                options={'compact': False, 'distance': 120, 'color': 'white', 'bg': '#2e3233'})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="d760a16b9548463e89a4eb221c4c58f8-0" class="displacy" width="1610" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: white; background: #2e3233; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">As</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">ações</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Magazine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Luiza</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">S.A.,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Franca,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">Brasil,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">acumuluram</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">baixa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">70%</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">ano.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d760a16b9548463e89a4eb221c4c58f8-0-0" stroke-width="2px" d="M70,302.0 C70,242.0 150.0,242.0 150.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d760a16b9548463e89a4eb221c4c58f8-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,304.0 L62,292.0 78,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d760a16b9548463e89a4eb221c4c58f8-0-1" stroke-width="2px" d="M190,302.0 C190,2.0 1010.0,2.0 1010.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d760a16b9548463e89a4eb221c4c58f8-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,304.0 L182,292.0 198,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d760a16b9548463e89a4eb221c4c58f8-0-2" stroke-width="2px" d="M310,302.0 C310,242.0 390.0,242.0 390.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d760a16b9548463e89a4eb221c4c58f8-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,304.0 L302,292.0 318,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d760a16b9548463e89a4eb221c4c58f8-0-3" stroke-width="2px" d="M190,302.0 C190,182.0 395.0,182.0 395.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d760a16b9548463e89a4eb221c4c58f8-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M395.0,304.0 L403.0,292.0 387.0,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d760a16b9548463e89a4eb221c4c58f8-0-4" stroke-width="2px" d="M430,302.0 C430,242.0 510.0,242.0 510.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d760a16b9548463e89a4eb221c4c58f8-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M510.0,304.0 L518.0,292.0 502.0,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d760a16b9548463e89a4eb221c4c58f8-0-5" stroke-width="2px" d="M430,302.0 C430,182.0 635.0,182.0 635.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d760a16b9548463e89a4eb221c4c58f8-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M635.0,304.0 L643.0,292.0 627.0,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d760a16b9548463e89a4eb221c4c58f8-0-6" stroke-width="2px" d="M430,302.0 C430,122.0 760.0,122.0 760.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d760a16b9548463e89a4eb221c4c58f8-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M760.0,304.0 L768.0,292.0 752.0,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d760a16b9548463e89a4eb221c4c58f8-0-7" stroke-width="2px" d="M430,302.0 C430,62.0 885.0,62.0 885.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d760a16b9548463e89a4eb221c4c58f8-0-7" class="displacy-la

# %% [markdown]
# # Gerenciamento de pipelines
#
# Você pode personalizar o Pipeline para ter apenas as etapas que você precisa

# %%
print("Pipeline Normal: ", nlp.pipe_names)
# Out:
# Pipeline Normal:  ['tok2vec', 'morphologizer', 'parser', 'lemmatizer', 'attribute_ruler', 'ner']

# %%
nlp.remove_pipe("tok2vec")
# Out:
# ('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7cdd516f6ff0>)

# %%
nlp.add_pipe('tok2vec', after='morphologizer')
print("Pipeline Normal: ", nlp.pipe_names)
# Out:
# Pipeline Normal:  ['morphologizer', 'tok2vec', 'parser', 'lemmatizer', 'attribute_ruler', 'ner']
