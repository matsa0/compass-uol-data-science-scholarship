# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import *
import matplotlib.pyplot as plt

import mlflow
import mlflow.sklearn
from mlflow.models.signature import infer_signature

# %%
credit = pd.read_csv('../Credit.csv')

# %%
credit.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
# 4                       3         'male single'          none  ...
#
#     property_magnitude age  other_payment_plans     housing existing_credits  \
# 0        'real estate'  67                 none         own                2
# 1        'real estate'  22                 none         own                1
# 2        'real estate'  49                 none         own                1
# 3     'life insurance'  45                 none  'for free'                1
# 4  'no known property'  53                 none  'for free'                2
#
#                     job num_dependents  own_telephone foreign_worker class
# 0               skilled              1            yes            yes  good
# 1               skilled              1           none            yes   bad
# 2  'unskilled resident'              2           none            yes  good
# 3               skilled              2           none            yes  good
# 4               skilled              2           none            yes   bad
#
# [5 rows x 21 columns]

# %%
credit.shape
# Out:
# (1000, 21)

# %%
credit.dtypes
# Out:
# checking_status           object
# duration                   int64
# credit_history            object
# purpose                   object
# credit_amount              int64
# savings_status            object
# employment                object
# installment_commitment     int64
# personal_status           object
# other_parties             object
# residence_since            int64
# property_magnitude        object
# age                        int64
# other_payment_plans       object
# housing                   object
# existing_credits           int64
# job                       object
# num_dependents             int64
# own_telephone             object
# foreign_worker            object
# class                     object
# dtype: object

# %% [markdown]
# Transformação básica de categórica pra numérica com o próprio pandas

# %%
for col in credit.columns:
    if credit[col].dtype == 'object':
        credit[col] = credit[col].astype('category').cat.codes

# %%
credit.head()
# Out:
#    checking_status  duration  credit_history  purpose  credit_amount  \
# 0                2         6               1        7           1169
# 1                1        48               3        7           5951
# 2                0        12               1        4           2096
# 3                2        42               3        5           7882
# 4                2        24               2        1           4870
#
#    savings_status  employment  installment_commitment  personal_status  \
# 0               0           3                       4                3
# 1               3           0                       2                0
# 2               3           1                       2                3
# 3               3           1                       2                3
# 4               3           0                       3                3
#
#    other_parties  ...  property_magnitude  age  other_payment_plans  housing  \
# 0              2  ...                   2   67                    1        1
# 1              2  ...                   2   22                    1        1
# 2              2  ...                   2   49                    1        1
# 3              1  ...                   0   45                    1        0
# 4              2  ...                   1   53                    1        0
#
#    existing_credits  job  num_dependents  own_telephone  foreign_worker  class
# 0                 2    3               1              1               1      1
# 1                 1    3               1              0               1      0
# 2                 1    2               2              0               1      1
# 3                 1    3               2              0               1      1
# 4                 2    3               2              0               1      0
#
# [5 rows x 21 columns]

# %%
X = credit.iloc[:, 0:20].values #vai de 0 a 19
y = credit.iloc[:, 20].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# # Criação do modelo e do experimento

# %%
def train_rf(n_estimators):
    mlflow. set_experiment("rfexperiment")
    
    with mlflow.start_run():
        rf =  RandomForestClassifier(n_estimators=n_estimators)
        rf.fit(X_train, y_train)
        prevs = rf.predict(X_test)
    
        #hyperparameters log
        mlflow.log_param("n_estimators", n_estimators)
        
        #metrics
        acc = accuracy_score(y_test, prevs)
        recall = recall_score(y_test, prevs)
        precision = precision_score(y_test, prevs)
        auc = roc_auc_score(y_test, prevs)
        log = log_loss(y_test, prevs)
    
        #register metrics
        mlflow.log_metric("Accuracy: ", acc)
        mlflow.log_metric("Recall: ", recall)
        mlflow.log_metric("Precision: ", precision)
        mlflow.log_metric("Auc: ", auc)
        mlflow.log_metric("Log: ", log)
    
        #plots
        confusion = ConfusionMatrixDisplay.from_estimator(rf, X_test, y_test)
        plt.savefig("confusionrf.png")
        roc = RocCurveDisplay.from_estimator(rf, X_test, y_test)
        plt.savefig("rocrf.png")
    
        #register plots
        mlflow.log_artifact("confusionrf.png")
        mlflow.log_artifact("rocrf.png")   
    
        #register model
        signature = infer_signature(X_train, rf.predict(X_train))
        mlflow.sklearn.log_model(rf,
                                 "RFmodel",
                                 signature=signature)
        
        #execution infos
        print("Model: ", mlflow.active_run().info.run_uuid)
    mlflow.end_run()

# %%
train_rf(200)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 train_rf(200)
#
# Cell In[59], line 2, in train_rf(n_estimators)
#       1 def train_rf(n_estimators):
# ----> 2     mlflow. set_experiment("rfexperiment")
#       4     with mlflow.start_run():
#       5         rf =  RandomForestClassifier(n_estimators=n_estimators)
#
# File ~/miniconda3/envs/mlflow/lib/python3.11/site-packages/mlflow/tracking/fluent.py:157, in set_experiment(experiment_name, experiment_id)
#     155 with _experiment_lock:
#     156     if experiment_id is None:
# --> 157         experiment = client.get_experiment_by_name(experiment_name)
#     158         if not experiment:
#     159             try:
#
# File ~/miniconda3/envs/mlflow/lib/python3.11/site-packages/mlflow/tracking/client.py:1293, in MlflowClient.get_experiment_by_name(self, name)
#    1261 def get_experiment_by_name(self, name: str) -> Optional[Experiment]:
#    1262     """Retrieve an experiment by experiment name from the backend store
#    1263
#    1264     Args:
#    (...)
#    1291         Lifecycle_stage: active
#    1292     """
# -> 1293     return self._tracking_client.get_experiment_by_name(name)
#
# File ~/miniconda3/envs/mlflow/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/client.py:502, in TrackingServiceClient.get_experiment_by_name(self, name)
#     494 def get_experiment_by_name(self, name):
#     495     """
#     496     Args:
#     497         name: The experiment name.
#    (...)
#     500         :py:class:`mlflow.entities.Experiment`
#     501     """
# --> 502     return self.store.get_experiment_by_name(name)
#
# File ~/miniconda3/envs/mlflow/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py:354, in FileStore.get_experiment_by_name(self, experiment_name)
#     346 def pagination_wrapper_func(number_to_get, next_page_token):
#     347     return self.search_experiments(
#     348         view_type=ViewType.ALL,
#     349         max_results=number_to_get,
#     350         filter_string=f"name = '{experiment_name}'",
#     351         page_token=next_page_token,
#     352     )
# --> 354 experiments = get_results_from_paginated_fn(
#     355     paginated_fn=pagination_wrapper_func,
#     356     max_results_per_page=SEARCH_MAX_RESULTS_THRESHOLD,
#     357     max_results=None,
#     358 )
#     359 return experiments[0] if len(experiments) > 0 else None
#
# File ~/miniconda3/envs/mlflow/lib/python3.11/site-packages/mlflow/utils/__init__.py:237, in get_results_from_paginated_fn(paginated_fn, max_results_per_page, max_results)
#     235     page_results = paginated_fn(num_to_get, next_page_token)
#     236 else:
# --> 237     page_results = paginated_fn(max_results_per_page, next_page_token)
#     238 all_results.extend(page_results)
#     239 if hasattr(page_results, "token") and page_results.token:
#
# File ~/miniconda3/envs/mlflow/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py:347, in FileStore.get_experiment_by_name.<locals>.pagination_wrapper_func(number_to_get, next_page_token)
#     346 def pagination_wrapper_func(number_to_get, next_page_token):
# --> 347     return self.search_experiments(
#     348         view_type=ViewType.ALL,
#     349         max_results=number_to_get,
#     350         filter_string=f"name = '{experiment_name}'",
#     351         page_token=next_page_token,
#     352     )
#
# File ~/miniconda3/envs/mlflow/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py:317, in FileStore.search_experiments(self, view_type, max_results, filter_string, order_by, page_token)
#     310 if max_results > SEARCH_MAX_RESULTS_THRESHOLD:
#     311     raise MlflowException(
#     312         f"Invalid value {max_results} for parameter 'max_results' supplied. It must be at "
#     313         f"most {SEARCH_MAX_RESULTS_THRESHOLD}",
#     314         INVALID_PARAMETER_VALUE,
#     315     )
# --> 317 self._check_root_dir()
#     318 experiment_ids = []
#     319 if view_type == ViewType.ACTIVE_ONLY or view_type == ViewType.ALL:
#
# File ~/miniconda3/envs/mlflow/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py:211, in FileStore._check_root_dir(self)
#     207 """
#     208 Run checks before running directory operations.
#     209 """
#     210 if not exists(self.root_directory):
# --> 211     raise Exception(f"'{self.root_directory}' does not exist.")
#     212 if not is_directory(self.root_directory):
#     213     raise Exception(f"'{self.root_directory}' is not a directory.")
#
# Exception: '/home/matsa/Documents/curso_mlops_mlflow/sec4/mlruns' does not exist.
